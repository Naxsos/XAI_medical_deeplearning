# %% [markdown]
# # Chest X-ray Classification and Localization using DenseNet
#
# This notebook implements a transfer learning approach using DenseNet for chest X-ray classification and localization on the NIH Chest X-ray dataset.

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.optim as optim
from torchvision import models
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
# Define paths
BASE_PATH = 'DL_for_HIN_Chest_X_Ray'
IMAGES_PATH = os.path.join(BASE_PATH, 'archive','images', 'images')
CSV_PATH = os.path.join(BASE_PATH, 'Data_Entry_2017_filtered_2.csv')
BBOX_PATH = os.path.join(BASE_PATH,'archive', 'BBox_List_2017.csv')

# Load the filtered dataset
df = pd.read_csv(CSV_PATH)
df.rename(columns={'Finding Labels': 'Finding Label'}, inplace=True)
df.drop(columns=['Follow-up #', 'Patient ID', 'Patient Age', 'Patient Gender', 'View Position', 'OriginalImage[Width','Height]', 'OriginalImagePixelSpacing[x', 'y]'], inplace=True)
no_finding_images = df[df['Finding Label'] == 'No Finding'].head(2016)


bbox_df = pd.read_csv(BBOX_PATH)
bbox_df.drop(columns=['Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'], inplace=True)
bbox_df.columns = ['Image Index','Finding Label', 'x', 'y', 'width', 'height']

combined_df = pd.concat([no_finding_images, bbox_df])

combined_df.shape
combined_df['Image Index'].value_counts()

combined_df[combined_df['Image Index'] == '00010277_000.png']
# Out:
#           Image Index Finding Label           x           y       width  \
# 326  00010277_000.png      Effusion  863.004444  693.229045   72.817778
# 474  00010277_000.png    Infiltrate  633.173333  416.749045  271.928889
# 590  00010277_000.png          Mass  297.528889  310.935712  540.444444
# 752  00010277_000.png     Pneumonia  642.275556  423.575712  265.102222
#
#          height
# 326  112.640000
# 474  221.866667
# 590  277.617778
# 752  223.004444

# %%
import os
from PIL import Image

# Define the new directory to save resized images
resized_images_dir = 'resized_images'
os.makedirs(resized_images_dir, exist_ok=True)  # Create the directory if it doesn't exist

# Strip whitespace from image filenames
combined_df['Image Index'] = combined_df['Image Index'].str.strip()

# Iterate over all images_[XXX] folders in the archive directory
archive_path = os.path.join('DL_for_HIN_Chest_X_Ray', 'archive')  # Adjust this path as needed

# Resize and save images
for index, row in combined_df.iterrows():
    image_name = row['Image Index']
    found = False  # Flag to check if the image was found

    # Walk through the archive directory
    for root, dirs, files in os.walk(archive_path):
        if image_name in files:
            image_path = os.path.join(root, image_name)  # Construct the full image path
            print(f"Found image: {image_path}")  # Debugging line
            found = True
            try:
                # Open the image
                with Image.open(image_path) as img:
                    # Resize the image
                    img_resized = img.resize((224, 224))
                    # Save the resized image to the new directory
                    img_resized.save(os.path.join(resized_images_dir, image_name))
                    print(f"Saved resized image: {image_name}")  # Debugging line
            except OSError as e:
                print(f"Error processing {image_name}: {e}")
            except Exception as e:
                print(f"Unexpected error with {image_name}: {e}")
            break  # Exit the loop once the image is found

    if not found:
        print(f"File does not exist in any subdirectory: {image_name}")
    print(index)
# Out:
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000002_000.png
# Saved resized image: 00000002_000.png
# 1
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000005_000.png
# Saved resized image: 00000005_000.png
# 3
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000005_001.png
# Saved resized image: 00000005_001.png
# 4
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000005_002.png
# Saved resized image: 00000005_002.png
# 5
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000005_003.png
# Saved resized image: 00000005_003.png
# 6
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000005_004.png
# Saved resized image: 00000005_004.png
# 7
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000005_005.png
# Saved resized image: 00000005_005.png
# 8
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000006_000.png
# Saved resized image: 00000006_000.png
# 10
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000007_000.png
# Saved resized image: 00000007_000.png
# 11
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000008_001.png
# Saved resized image: 00000008_001.png
# 12
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000011_001.png
# Saved resized image: 00000011_001.png
# 15
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000011_002.png
# Saved resized image: 00000011_002.png
# 16
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000011_003.png
# Saved resized image: 00000011_003.png
# 17
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000011_004.png
# Saved resized image: 00000011_004.png
# 18
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000011_008.png
# Saved resized image: 00000011_008.png
# 22
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000013_000.png
# Saved resized image: 00000013_000.png
# 24
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000013_008.png
# Saved resized image: 00000013_008.png
# 27
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000013_014.png
# Saved resized image: 00000013_014.png
# 29
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000013_015.png
# Saved resized image: 00000013_015.png
# 30
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000013_016.png
# Saved resized image: 00000013_016.png
# 31
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000013_017.png
# Saved resized image: 00000013_017.png
# 32
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000013_019.png
# Saved resized image: 00000013_019.png
# 33
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000013_038.png
# Saved resized image: 00000013_038.png
# 43
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000014_000.png
# Saved resized image: 00000014_000.png
# 45
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000015_000.png
# Saved resized image: 00000015_000.png
# 46
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000016_000.png
# Saved resized image: 00000016_000.png
# 47
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000017_001.png
# Saved resized image: 00000017_001.png
# 48
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000017_002.png
# Saved resized image: 00000017_002.png
# 49
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000018_000.png
# Saved resized image: 00000018_000.png
# 50
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000022_000.png
# Saved resized image: 00000022_000.png
# 54
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000023_000.png
# Saved resized image: 00000023_000.png
# 55
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000023_001.png
# Saved resized image: 00000023_001.png
# 56
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000023_003.png
# Saved resized image: 00000023_003.png
# 57
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000029_000.png
# Saved resized image: 00000029_000.png
# 61
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000031_000.png
# Saved resized image: 00000031_000.png
# 64
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_002.png
# Saved resized image: 00000032_002.png
# 66
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_003.png
# Saved resized image: 00000032_003.png
# 67
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_005.png
# Saved resized image: 00000032_005.png
# 69
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_008.png
# Saved resized image: 00000032_008.png
# 71
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_009.png
# Saved resized image: 00000032_009.png
# 72
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_010.png
# Saved resized image: 00000032_010.png
# 73
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_019.png
# Saved resized image: 00000032_019.png
# 81
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_020.png
# Saved resized image: 00000032_020.png
# 82
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_022.png
# Saved resized image: 00000032_022.png
# 83
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_025.png
# Saved resized image: 00000032_025.png
# 85
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_042.png
# Saved resized image: 00000032_042.png
# 92
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_046.png
# Saved resized image: 00000032_046.png
# 94
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_048.png
# Saved resized image: 00000032_048.png
# 96
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_049.png
# Saved resized image: 00000032_049.png
# 97
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000032_051.png
# Saved resized image: 00000032_051.png
# 98
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000034_001.png
# Saved resized image: 00000034_001.png
# 102
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000035_000.png
# Saved resized image: 00000035_000.png
# 103
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000035_001.png
# Saved resized image: 00000035_001.png
# 104
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000037_000.png
# Saved resized image: 00000037_000.png
# 105
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000038_002.png
# Saved resized image: 00000038_002.png
# 107
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000038_004.png
# Saved resized image: 00000038_004.png
# 108
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000038_005.png
# Saved resized image: 00000038_005.png
# 109
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000038_007.png
# Saved resized image: 00000038_007.png
# 110
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000039_000.png
# Saved resized image: 00000039_000.png
# 111
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000112_001.png
# Saved resized image: 00000112_001.png
# 287
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000113_000.png
# Saved resized image: 00000113_000.png
# 288
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000115_000.png
# Saved resized image: 00000115_000.png
# 290
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000116_027.png
# Saved resized image: 00000116_027.png
# 308
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000116_030.png
# Saved resized image: 00000116_030.png
# 310
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000116_038.png
# Saved resized image: 00000116_038.png
# 315
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000116_039.png
# Saved resized image: 00000116_039.png
# 316
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000118_008.png
# Saved resized image: 00000118_008.png
# 323
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000118_012.png
# Saved resized image: 00000118_012.png
# 324
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000118_014.png
# Saved resized image: 00000118_014.png
# 326
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000118_016.png
# Saved resized image: 00000118_016.png
# 328
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000121_000.png
# Saved resized image: 00000121_000.png
# 332
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000121_001.png
# Saved resized image: 00000121_001.png
# 333
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000121_002.png
# Saved resized image: 00000121_002.png
# 334
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000121_003.png
# Saved resized image: 00000121_003.png
# 335
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000121_004.png
# Saved resized image: 00000121_004.png
# 336
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000121_005.png
# Saved resized image: 00000121_005.png
# 337
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000121_008.png
# Saved resized image: 00000121_008.png
# 340
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000121_009.png
# Saved resized image: 00000121_009.png
# 341
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000122_000.png
# Saved resized image: 00000122_000.png
# 342
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000126_000.png
# Saved resized image: 00000126_000.png
# 345
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000127_000.png
# Saved resized image: 00000127_000.png
# 346
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000127_001.png
# Saved resized image: 00000127_001.png
# 347
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000127_006.png
# Saved resized image: 00000127_006.png
# 352
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000127_008.png
# Saved resized image: 00000127_008.png
# 354
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000129_000.png
# Saved resized image: 00000129_000.png
# 355
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000129_001.png
# Saved resized image: 00000129_001.png
# 356
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000130_000.png
# Saved resized image: 00000130_000.png
# 357
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000132_000.png
# Saved resized image: 00000132_000.png
# 359
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000133_001.png
# Saved resized image: 00000133_001.png
# 365
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000133_002.png
# Saved resized image: 00000133_002.png
# 366
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000135_000.png
# Saved resized image: 00000135_000.png
# 368
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000135_001.png
# Saved resized image: 00000135_001.png
# 369
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000136_000.png
# Saved resized image: 00000136_000.png
# 370
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000137_000.png
# Saved resized image: 00000137_000.png
# 371
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000137_001.png
# Saved resized image: 00000137_001.png
# 372
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000138_000.png
# Saved resized image: 00000138_000.png
# 373
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000138_001.png
# Saved resized image: 00000138_001.png
# 374
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000138_003.png
# Saved resized image: 00000138_003.png
# 376
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000139_000.png
# Saved resized image: 00000139_000.png
# 378
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000139_001.png
# Saved resized image: 00000139_001.png
# 379
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000139_002.png
# Saved resized image: 00000139_002.png
# 380
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000140_000.png
# Saved resized image: 00000140_000.png
# 381
# Found image: DL_for_HIN_Chest_X_Ray/archive/images_001/images/00000141_000.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[144], line 29
#      25 try:
#      26     # Open the image
#      27     with Image.open(image_path) as img:
#      28         # Resize the image
# ---> 29         img_resized = img.resize((224, 224))
#      30         # Save the resized image to the new directory
#      31         img_resized.save(os.path.join(resized_images_dir, image_name))
#
# File ~/Documents/GitHub/MedicaldeepLearning/.venvVS/lib/python3.12/site-packages/PIL/Image.py:2341, in Image.resize(self, size, resample, box, reducing_gap)
#    2338     resample = Resampling.NEAREST
#    2340 if self.mode in ["LA", "RGBA"] and resample != Resampling.NEAREST:
# -> 2341     im = self.convert({"LA": "La", "RGBA": "RGBa"}[self.mode])
#    2342     im = im.resize(size, resample, box)
#    2343     return im.convert(self.mode)
#
# File ~/Documents/GitHub/MedicaldeepLearning/.venvVS/lib/python3.12/site-packages/PIL/Image.py:993, in Image.convert(self, mode, matrix, dither, palette, colors)
#     990 if mode in ("BGR;15", "BGR;16", "BGR;24"):
#     991     deprecate(mode, 12)
# --> 993 self.load()
#     995 has_transparency = "transparency" in self.info
#     996 if not mode and self.mode == "P":
#     997     # determine default mode
#
# File ~/Documents/GitHub/MedicaldeepLearning/.venvVS/lib/python3.12/site-packages/PIL/ImageFile.py:300, in ImageFile.load(self)
#     297         raise OSError(msg)
#     299 b = b + s
# --> 300 n, err_code = decoder.decode(b)
#     301 if n < 0:
#     302     break
#
# KeyboardInterrupt:

# %%
combined_df.to_csv('bbox_resized_filtered_images.csv', index=False)

# %% [markdown]
# ## Training Model

# %%
IMAGES_PATH_RESIZED = os.path.join('resized_images')
PREPROCESSED_IMAGES_PATH = os.path.join('bbox_resized_filtered_images.csv')
df_preprocessed = pd.read_csv(PREPROCESSED_IMAGES_PATH)

# %%
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class ChestXrayDataset(Dataset):
    def __init__(self, image_dir, df, transform=None):
        self.image_dir = image_dir
        self.df = df
        self.transform = transform
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        img_name = self.df.iloc[idx]['Image Index']
        img_path = os.path.join(self.image_dir, img_name)
        image = Image.open(img_path).convert('RGB')
        
        if self.transform:
            image = self.transform(image)
            
        # Get labels (binary classification: normal vs abnormal)
        label = 1 if self.df.iloc[idx]['Finding Label'] != 'No Finding' else 0
        return image, torch.tensor(label, dtype=torch.float32)
# Out:
# Using device: cuda

# %%
import torch
print(torch.cuda.is_available())  # Should return True
print(torch.cuda.device_count())  # Should return > 0
print(torch.cuda.get_device_name(0))  # Should return the name of the GPU
# Out:
# True
# 1
# NVIDIA A40

# %%
def get_transforms():
    """Define image transformations."""
    return {
        'train': transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.RandomHorizontalFlip(),
            
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'val': transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ])
    }

# Split data and create data loaders
train_df, temp_df = train_test_split(df_preprocessed, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Get transforms
transforms_dict = get_transforms()

# Create datasets
train_dataset = ChestXrayDataset(IMAGES_PATH_RESIZED, train_df, transform=transforms_dict['train'])
val_dataset = ChestXrayDataset(IMAGES_PATH_RESIZED, val_df, transform=transforms_dict['val'])
test_dataset = ChestXrayDataset(IMAGES_PATH_RESIZED, test_df, transform=transforms_dict['val'])

# Create data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)

print(f"Training samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")
# Out:
# Training samples: 2400
# Validation samples: 300
# Test samples: 300

# %%
from torchvision import models

def create_model():
    """Create a DenseNet model with transfer learning."""
    # Load pre-trained DenseNet
    model = models.densenet121(pretrained=True)
    
    # Freeze all layers
    for param in model.parameters():
        param.requires_grad = False
    
    # Replace the classifier
    num_features = model.classifier.in_features
    model.classifier = nn.Sequential(
        nn.Linear(num_features, 512),
        nn.ReLU(),
        nn.Dropout(0.3),
        nn.Linear(512, 1),
        nn.Sigmoid()
    )
    
    return model.to(device)

# Create model
model = create_model()
#print(model)
# Out:
# /root/XAI_medical_deeplearning/myvenv/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /root/XAI_medical_deeplearning/myvenv/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def train_model(model, train_loader, val_loader, num_epochs=10):
    """Train the model."""
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
    
    best_val_loss = float('inf')
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        train_correct = 0
        train_total = 0
        
        for images, labels in tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs}'):
            images = images.to(device)
            labels = labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs.squeeze(), labels)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            predicted = (outputs.squeeze() > 0.5).float()
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()
        
        avg_train_loss = train_loss / len(train_loader)
        train_accuracy = 100 * train_correct / train_total
        train_losses.append(avg_train_loss)
        
        # Validation phase
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs.squeeze(), labels)
                
                val_loss += loss.item()
                predicted = (outputs.squeeze() > 0.5).float()
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
        
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_losses.append(avg_val_loss)
        
        print(f'Epoch {epoch+1}/{num_epochs}:')
        print(f'Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%')
        print(f'Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')
        
        # Save best model
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), 'best_densenet_model.pth')
            print('Model saved!')
        
        print('-' * 60)
    
    return train_losses, val_losses

def plot_training_history(train_losses, val_losses):
    """Plot training history."""
    plt.figure(figsize=(10, 6))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# Train the model
train_losses, val_losses = train_model(model, train_loader, val_loader, num_epochs=10)

# Plot training history
plot_training_history(train_losses, val_losses)
# Out:
# Epoch 1/10: 100%|██████████| 75/75 [00:03<00:00, 23.23it/s]
# Epoch 1/10:
# Training Loss: 0.6043, Training Accuracy: 67.83%
# Validation Loss: 0.5301, Validation Accuracy: 74.33%
# Model saved!
# ------------------------------------------------------------
# Epoch 2/10: 100%|██████████| 75/75 [00:02<00:00, 25.47it/s]
# Epoch 2/10:
# Training Loss: 0.5225, Training Accuracy: 73.50%
# Validation Loss: 0.4847, Validation Accuracy: 76.67%
# Model saved!
# ------------------------------------------------------------
# Epoch 3/10: 100%|██████████| 75/75 [00:02<00:00, 26.19it/s]
# Epoch 3/10:
# Training Loss: 0.5066, Training Accuracy: 75.54%
# Validation Loss: 0.4796, Validation Accuracy: 76.00%
# Model saved!
# ------------------------------------------------------------
# Epoch 4/10: 100%|██████████| 75/75 [00:02<00:00, 26.22it/s]
# Epoch 4/10:
# Training Loss: 0.4839, Training Accuracy: 76.50%
# Validation Loss: 0.4870, Validation Accuracy: 76.33%
# ------------------------------------------------------------
# Epoch 5/10: 100%|██████████| 75/75 [00:02<00:00, 26.36it/s]
# Epoch 5/10:
# Training Loss: 0.4876, Training Accuracy: 75.88%
# Validation Loss: 0.4767, Validation Accuracy: 77.00%
# Model saved!
# ------------------------------------------------------------
# Epoch 6/10: 100%|██████████| 75/75 [00:02<00:00, 26.02it/s]
# Epoch 6/10:
# Training Loss: 0.4663, Training Accuracy: 77.79%
# Validation Loss: 0.5442, Validation Accuracy: 72.00%
# ------------------------------------------------------------
# Epoch 7/10: 100%|██████████| 75/75 [00:02<00:00, 25.62it/s]
# Epoch 7/10:
# Training Loss: 0.4696, Training Accuracy: 77.83%
# Validation Loss: 0.4729, Validation Accuracy: 77.00%
# Model saved!
# ------------------------------------------------------------
# Epoch 8/10: 100%|██████████| 75/75 [00:02<00:00, 25.96it/s]
# Epoch 8/10:
# Training Loss: 0.4464, Training Accuracy: 79.17%
# Validation Loss: 0.5028, Validation Accuracy: 75.00%
# ------------------------------------------------------------
# Epoch 9/10: 100%|██████████| 75/75 [00:02<00:00, 26.02it/s]
# Epoch 9/10:
# Training Loss: 0.4479, Training Accuracy: 78.83%
# Validation Loss: 0.4842, Validation Accuracy: 78.00%
# ------------------------------------------------------------
# Epoch 10/10: 100%|██████████| 75/75 [00:02<00:00, 25.82it/s]
# Epoch 10/10:
# Training Loss: 0.4449, Training Accuracy: 79.00%
# Validation Loss: 0.5323, Validation Accuracy: 77.00%
# ------------------------------------------------------------
